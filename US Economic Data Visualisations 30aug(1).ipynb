# %%
import pandas as pd
import math as math
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import sandplot as sp

cols=[]
cols.append(0)
cols.append(1)
cols.append(2)
cols.append(3)
cols.append(4)
cols.append(5)
cols.append(6)
pd.options.display.max_rows = 4


data = pd.read_csv("/Users/harry/Dropbox (Sandtable)/Root/Harry Workspace/US economic data/US economic data/economic data together.csv", usecols = cols,delimiter=',', encoding="utf-8-sig", nrows = 125
            )
print('US Economic Data')
print('DATA SOURCE: http://www.tradingeconomics.com/')
data
# Out:
# US Economic Data
# DATA SOURCE: http://www.tradingeconomics.com/
#           Date  US Inflation Rate by Month  \
# 0    Mar, 2006                         3.4
# 1    Apr, 2006                         3.5
# ..         ...                         ...
# 123  Jun, 2016                         1.0
# 124  Jul, 2016                         0.8
#
#      Seasonally adjusted dollars per hour  \
# 0                                   20.04
# 1                                   20.15
# ..                                    ...
# 123                                 25.61
# 124                                 25.69
#
#      Consumer Price Index - FOOD & BEVERAGES  \
# 0                                    194.400
# 1                                    194.300
# ..                                       ...
# 123                                  247.514
# 124                                  247.477
#
# ...

# %%
data2 = pd.read_csv("/Users/harry/Dropbox (Sandtable)/Root/Harry Workspace/US economic data/US economic data/economic data together.csv",header = None, usecols = cols,delimiter=',', encoding="utf-8-sig", nrows = 126)
date=data2[0].tolist()
inflation=data2[1].tolist()
pay=data2[2].tolist()
CPI=data2[3].tolist()
RGDP=data2[4].tolist()
ex_rate=data2[5].tolist()
unemployment=data2[6].tolist()
date.remove(date[0])
inflation.remove(inflation[0])
pay.remove(pay[0])
CPI.remove(CPI[0])
RGDP.remove(RGDP[0])
ex_rate.remove(ex_rate[0])
unemployment.remove(unemployment[0])

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt


dates = []
for month in range(3, 13):
        dates.append(dt.datetime(year=2006, month=month, day=1))
for year in range(2007, 2016):
    for month in range(1, 13):
        dates.append(dt.datetime(year=year, month=month, day=1))
for month in range(1, 8):
        dates.append(dt.datetime(year=2016, month=month, day=1))

# %%
inflation1 =[]
for i in inflation:
    inflation1.append(float(str(i))-float(str(inflation[0])))
pay1 =[]
for i in pay:
    pay1.append(float(str(i))-float(str(pay[0])))
CPI1 =[]
for i in CPI:
    CPI1.append(((float(str(i))-float(str(CPI[0])))/10))
RGDP1 =[]
for i in RGDP:
    RGDP1.append(float(str(i))-float(str(RGDP[0])))
ex_rate1 =[]
for i in ex_rate:
    ex_rate1.append(float(str(i))-float(str(ex_rate[0])))
unemployment1 =[]
for i in unemployment:
    unemployment1.append(float(str(i))-float(str(unemployment[0])))

# %%
import matplotlib
# %matplotlib inline
fig, ax = plt.subplots(figsize = (20,10))
sp.prep_plot(ax=ax)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.tick_params(labelsize=15)

plt.ylabel('Variation in arbitrary units', fontsize = '20')
plt.plot(dates, inflation1, color = 'green', label = 'Inflation Rate')
plt.plot(dates, pay1, color = 'blue',label = 'Seasonally Adjusted Dollars per Hour')
plt.plot(dates, CPI1,color = 'purple',label = 'Consumer Price Index - FOOD & BEVERAGES')
plt.plot(dates, RGDP1,color = 'orange',label = 'Real gross domestic product (percent change from  \npreceding period,seasonally adjusted annual rate)')
plt.plot(dates, ex_rate1,color = 'black',label = 'GBP/USD exchange rate')
plt.plot(dates, unemployment1,color = 'red',label = 'Civillian Unemployment Rate (Percent,Seasonally Adjusted)')
plt.legend(loc=0,prop={'size':15})
plt.title(" US Economic Variables 2006 - 2016", fontsize = 20,position=(0.5, 1.03))
plt.show()

# %%
# %matplotlib inline

inflation_prediction = [1.2,1.5,1.6,1.7,2.5]
dates_prediction =[]
dates_prediction.append(datetime.datetime(2016, 9, 1, 0, 0))
dates_prediction.append(datetime.datetime(2016, 12, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 3, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 6, 1, 0, 0))
dates_prediction.append(datetime.datetime(2020, 1, 1, 0, 0))

plt.figure(figsize=(30,20))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.ylabel('Inflation Rate Percentage', fontsize = '30')
plt.plot(dates, inflation, color = 'green',marker = 'o', label = 'historical')
plt.plot(dates_prediction, inflation_prediction, color = 'grey',marker = "o", label = 'predicted')
plt.legend(loc=0,prop={'size':30})
plt.title("US Inflation 2006 - 2020", fontsize = 30,position=(0.5, 1.03))
plt.show()

# %%
plt.figure(figsize=(30,20))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.ylabel('Seasonally Adjusted Dollars per Hour (USD)', fontsize = '30')
plt.plot(dates, pay, color = 'blue', marker = 'o')


plt.title("US Wages 2006 - 2016", fontsize = 30,position=(0.5, 1.03))
plt.show()

# %%
CPI_prediction=[248,249,250,252,276]
dates_prediction =[]
dates_prediction.append(datetime.datetime(2016, 9, 1, 0, 0))
dates_prediction.append(datetime.datetime(2016, 12, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 3, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 6, 1, 0, 0))
dates_prediction.append(datetime.datetime(2020, 1, 1, 0, 0))

plt.figure(figsize=(30,20))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.ylabel('CPI - Food & Beverages (USD)', fontsize = '30')
plt.plot(dates, CPI, color = 'purple', marker = 'o', label = 'historical')

plt.plot(dates_prediction, CPI_prediction, color = 'grey',marker = "o", label = 'predicted')
plt.legend(loc=2,prop={'size':30})

plt.title("US Consumer Price Index - Food & Beverages 2006 - 2020", fontsize = 30,position=(0.5, 1.03))
plt.show()

# %%
GDP_prediction=[1.9,2.2,2.5,2.6,2.1]
dates_prediction=[]
dates_prediction.append(datetime.datetime(2016, 8, 1, 0, 0))
dates_prediction.append(datetime.datetime(2016, 9, 1, 0, 0))
dates_prediction.append(datetime.datetime(2016, 12, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 3, 1, 0, 0))
dates_prediction.append(datetime.datetime(2020, 6, 1, 0, 0))
plt.figure(figsize=(30,20))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.ylabel('Real GDP (percentage change)', fontsize = '30')
plt.plot(dates, RGDP, color = 'orange',marker = 'o', label = 'historical')
plt.plot(dates_prediction, GDP_prediction, color = 'grey',marker = "o", label = 'predicted')
plt.legend(loc=2,prop={'size':30})

plt.title("US Real GDP \n (Percent Change from Preceding Period, \n Seasonally Adjusted Annual Rate)  \n 2006 - 2020", fontsize = 30,position=(0.5, 1.03))
plt.show()

# %%
ex_rate_prediction=[1.32,1.39,1.26,1.23,1.25]
dates_prediction=[]
dates_prediction.append(datetime.datetime(2016, 8, 1, 0, 0))
dates_prediction.append(datetime.datetime(2016, 9, 1, 0, 0))
dates_prediction.append(datetime.datetime(2016, 12, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 3, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 6, 1, 0, 0))
plt.figure(figsize=(30,20))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.ylabel('Exchange Rate', fontsize = '30')
plt.plot(dates, ex_rate, color = 'green',marker = 'o', label = 'historical')
plt.plot(dates_prediction, ex_rate_prediction, color = 'grey',marker = "o", label = 'predicted')
plt.legend(loc=0,prop={'size':30})

plt.title("GBP/USD Exchange Rate 2006 - 2020", fontsize = 30,position=(0.5, 1.03))
plt.show()

# %%
unemployment_prediction = [5.1,5.2,5.3,5.3,6]
dates_prediction =[]
dates_prediction.append(datetime.datetime(2016, 9, 1, 0, 0))
dates_prediction.append(datetime.datetime(2016, 12, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 3, 1, 0, 0))
dates_prediction.append(datetime.datetime(2017, 6, 1, 0, 0))
dates_prediction.append(datetime.datetime(2020, 1, 1, 0, 0))

plt.figure(figsize=(30,20))
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.ylabel('Unemployment Rate (percentage)', fontsize = '30')
plt.plot(dates, unemployment, color = 'red',marker = 'o', label = 'historical')
plt.plot(dates_prediction, unemployment_prediction, color = 'grey',marker = "o", label = 'predicted')
plt.ylim([4,10.5])
plt.legend(loc=0,prop={'size':30})
plt.title("US Civillian Unemployment Rate \n (percent, seasonally adjusted) \n 2006 - 2020", fontsize = 30,position=(0.5, 1.03))
plt.show()
